# %% [markdown]
# # Compare Excel Files

# %%
import pandas as pd
import os.path as op

FILE_1_PATH = r"../../data/predictions_datasets/brca_prediction_2021-10-26/632d9021/brca_preliminary_data_cgc_2021-10-26.xlsx"
FILE_2_PATH = r"../../data/predictions_datasets/brca_prediction_2021-11-05_test/test/brca_preliminary_data_cgc_2021-11-05.xlsx"

file_1 = pd.read_excel(FILE_1_PATH)
file_2 = pd.read_excel(FILE_2_PATH)

print(file_1.equals(file_2))

# print(op.isfile(FILE_1_PATH))
# print(op.isfile(FILE_2_PATH))
# Out:
# False

# %%
file_1.iloc[:, 2:-2].equals(file_2.iloc[:, 2:-2])
# Out:
# True

# %%
file_1.head()
# Out:
#   PROTEIN    GENE  NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 0  A0AV96   RBM47                              0                       0
# 1  A0AVI2  FER1L5                              0                       0
# 2  A0AVT1    UBA6                             14                       3
# 3  A0FGR9   ESYT3                              2                       1
# 4  A0PJE2  DHRS12                              0                       0
#
#    NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 0                       0                       0                   2
# 1                       0                       0                   4
# 2                      11                       7                   4
# 3                       1                       1                   1
# 4                       0                       0                   1
#
#    PATIENT_INTERFACE_COUNT  BASELINE  OUR_METHOD  OUR_METHOD/BASELINE  \
# ...

# %%
file_2.head()
# Out:
#   PROTEIN    GENE  NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 0  A0AV96   RBM47                              0                       0
# 1  A0AVI2  FER1L5                              0                       0
# 2  A0AVT1    UBA6                             14                       3
# 3  A0FGR9   ESYT3                              2                       1
# 4  A0PJE2  DHRS12                              0                       0
#
#    NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 0                       0                       0                   2
# 1                       0                       0                   4
# 2                      11                       7                   4
# 3                       1                       1                   1
# 4                       0                       0                   1
#
#    PATIENT_INTERFACE_COUNT  BASELINE  OUR_METHOD  OUR_METHOD/BASELINE  \
# ...

# %%
file_1.iloc[:, 2:]
# Out:
#       NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 0                                 0                       0
# 1                                 0                       0
# 2                                14                       3
# 3                                 2                       1
# 4                                 0                       0
# ...                             ...                     ...
# 8418                              2                       1
# 8419                              0                       0
# 8420                              0                       0
# 8421                              0                       0
# 8422                              0                       0
#
#       NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 0                          0                       0                   2
# 1                          0                       0                   4
# ...

# %%
with open("brca_proteins.txt", "w") as fout:
    for protein in file_1["PROTEIN"]:
        fout.write(f"{protein}\n")

# %%
file_1["CGC_STATUS"].value_counts()
# Out:
# -    7994
# +     429
# Name: CGC_STATUS, dtype: int64

# %%
with open("brca_genes_API.txt", "w") as fout:
    for gene in file_2["GENE"]:
        fout.write(f"{gene}\n")

# %%
file_1["CGC_STATUS"].value_counts()
# Out:
# -    7994
# +     429
# Name: CGC_STATUS, dtype: int64

# %%
file_2["CGC_STATUS"].value_counts()
# Out:
# -    7999
# +     424
# Name: CGC_STATUS, dtype: int64

# %%
file_2.iloc[:, 2:]
# Out:
#       NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 0                                 0                       0
# 1                                 0                       0
# 2                                14                       3
# 3                                 2                       1
# 4                                 0                       0
# ...                             ...                     ...
# 8418                              2                       1
# 8419                              0                       0
# 8420                              0                       0
# 8421                              0                       0
# 8422                              0                       0
#
#       NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 0                          0                       0                   2
# 1                          0                       0                   4
# ...

# %%
file_1.iloc[:, :2]
# Out:
#      PROTEIN      GENE
# 0     A0AV96     RBM47
# 1     A0AVI2    FER1L5
# 2     A0AVT1      UBA6
# 3     A0FGR9     ESYT3
# 4     A0PJE2    DHRS12
# ...      ...       ...
# 8418  Q9Y6X6     MYO16
# 8419  Q9Y6X8      ZHX2
# 8420  Q9Y6Y0  IVNS1ABP
# 8421  Q9Y6Y1    CAMTA1
# 8422  Q9Y6Z7   COLEC10
#
# [8423 rows x 2 columns]

# %%
def compare_dfs(df1, df2):
    return df1.equals(df2)

# %%
from tqdm.notebook import tqdm

# %%
for i in tqdm(range(len(file_1))):
    if i in [1044, 2616, 6006, 6517, 6789]:
        continue
    assert compare_dfs(file_1.iloc[[i], 2:], file_2.iloc[[i], 2:]), f"i={i}"
# Out:
#   0%|          | 0/8423 [00:00<?, ?it/s]

# %%
file_1[file_1["GENE"].isna()]
# Out:
#      PROTEIN GENE  NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 1186  P04745  NaN                              0                       0
# 1191  P04908  NaN                              2                       1
# 1408  P0C0S8  NaN                              2                       2
# 1535  P12532  NaN                              0                       0
# 3048  P62805  NaN                             64                      54
# 3049  P62807  NaN                             10                       4
# 3082  P68431  NaN                             33                      28
# 3583  Q13748  NaN                              0                       0
# 4342  Q5VU13  NaN                              0                       0
#
#       NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 1186                       0                       0                   4
# 1191                       1                       1                  11
# ...

# %%
file_2[file_2["GENE"].isna()]
# Out:
#      PROTEIN GENE  NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 23    A2BFH1  NaN                              0                       0
# 564   O60344  NaN                              0                       0
# 1186  P04745  NaN                              0                       0
# 3031  P62158  NaN                              7                       6
# 3583  Q13748  NaN                              0                       0
# 4233  Q5JXX5  NaN                              0                       0
# 4342  Q5VU13  NaN                              0                       0
# 8154  Q9Y2S0  NaN                              1                       0
#
#       NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 23                         0                       0                   2
# 564                        0                       0                   6
# 1186                       0                       0                   4
# ...

# %% [raw]
# P68431
# P62805

# %%
from IPython.display import display

# %%
entries = []
for k in [1044, 2616, 6006, 6517, 6789]:
    entries.append((file_1.loc[k, 'PROTEIN'], file_1.loc[k, 'GENE'], file_1.loc[k, 'CGC_STATUS']))
    entries.append((file_2.loc[k, 'PROTEIN'], file_2.loc[k, 'GENE'], file_2.loc[k, 'CGC_STATUS']))
    
#     print(f"{file_1.loc[k, 'PROTEIN']} \t {file_1.loc[k, 'GENE']} \t {' ': <5} {file_1.loc[k, 'CGC_STATUS']}")
#     print(f"{file_2.loc[k, 'PROTEIN']} \t {file_2.loc[k, 'GENE']} \t {' ': <5} {file_2.loc[k, 'CGC_STATUS']}")
#     display(file_1.iloc[[k], :])
#     display(file_2.iloc[[k], :])
#     print("\n=================================================================================================")

# %%
pd.DataFrame(entries, columns=["PROTEIN", "GENE", "CGC_STATUS"])
# Out:
#   PROTEIN     GENE CGC_STATUS
# 0  O96028    WHSC1          +
# 1  O96028     NSD2          -
# 2  P49589     CARS          +
# 3  P49589    CARS1          -
# 4  Q969V6     MKL1          +
# 5  Q969V6    MRTFA          -
# 6  Q99719    SEPT5          +
# 7  Q99719  SEPTIN5          -
# 8  Q9BZ95  WHSC1L1          +
# 9  Q9BZ95     NSD3          -

# %%
file_1.iloc[[i], :]
# Out:
#      PROTEIN   GENE  NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 1044  O96028  WHSC1                              0                       0
#
#       NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 1044                       0                       0                   2
#
#       PATIENT_INTERFACE_COUNT  BASELINE  OUR_METHOD  OUR_METHOD/BASELINE  \
# 1044                        0         0           0                  NaN
#
#       ELASPIC_COVERAGE CGC_STATUS CGC_STATUS (BRCA)
# 1044                 2          +                 -

# %%
file_2.iloc[[i], :]
# Out:
#      PROTEIN  GENE  NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 1044  O96028  NSD2                              0                       0
#
#       NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 1044                       0                       0                   2
#
#       PATIENT_INTERFACE_COUNT  BASELINE  OUR_METHOD  OUR_METHOD/BASELINE  \
# 1044                        0         0           0                  NaN
#
#       ELASPIC_COVERAGE CGC_STATUS CGC_STATUS (BRCA)
# 1044                 2          -                 -

# %%
file_1.shape, file_2.shape
# Out:
# ((8423, 14), (8423, 14))

# %%
# Out:
# True

# %%
file_2[file_2["PROTEIN"] == "P68431"]
# Out:
#      PROTEIN  GENE  NUM_ELASPIC_INTERFACE_ENTRIES  NUM_DISRUPTIVE_ENTRIES  \
# 3082  P68431  H3C1                             33                      28
#
#       NUM_INCR_NOEFF_ENTRIES  NUM_UNIQUE_INTERACTORS  PATIENT_CORE_COUNT  \
# 3082                       5                      11                   1
#
#       PATIENT_INTERFACE_COUNT  BASELINE  OUR_METHOD  OUR_METHOD/BASELINE  \
# 3082                       11        40          35                0.875
#
#       ELASPIC_COVERAGE CGC_STATUS CGC_STATUS (BRCA)
# 3082                12          -                 -

# %%
file_2.iloc[:, :2]
# Out:
#      PROTEIN      GENE
# 0     A0AV96     RBM47
# 1     A0AVI2    FER1L5
# 2     A0AVT1      UBA6
# 3     A0FGR9     ESYT3
# 4     A0PJE2    DHRS12
# ...      ...       ...
# 8418  Q9Y6X6     MYO16
# 8419  Q9Y6X8      ZHX2
# 8420  Q9Y6Y0  IVNS1ABP
# 8421  Q9Y6Y1    CAMTA1
# 8422  Q9Y6Z7   COLEC10
#
# [8423 rows x 2 columns]

# %%
file_1.iloc[:, :2].equals(file_2.iloc[:, :2])
# Out:
# False

# %%
file_1.iloc[:, 2:].equals(file_2.iloc[:, 2:])
# Out:
# False
