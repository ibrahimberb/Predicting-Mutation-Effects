# %%
import os
import os.path as op

os.chdir('../../')

# os.listdir()

# %%
from helpers.helpers_analysis.justify_sampling import (
    MutationJustifier
)

# %%
TRAINING_DATA_PATH = "processed_data_740.csv"

# Reflect changes in the modules immediately.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# A,x, için B ve C interactor'ları olsun.
# A,y için D ve E interactor'ları olsun.
#
# protein, interactor yaparsan common interactor yok ki..
#
# ama yapman gereken B-C, B-D, B-E, C-D,C-E arasında corelasyon hesaplayıp bir variable'e eklemen. sonra ortalama gösterebilirsin..

# %%
mutation_justifier = MutationJustifier(TRAINING_DATA_PATH)
# Out:
#   0%|          | 0/164 [00:00<?, ?it/s]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 110                      1     O00311     I99T                Q9UBU7
# 438                      1     O00311     I99L                Q9UBU7
# 492                      1     O00311    K416T                Q9UBU7
# 549                      1     O00311    Q106R                Q9UBU7
#
#      Template_sequence_identity  Alignment_score  \
# 110                      1.0000         0.741935
# 438                      1.0000         0.741935
# 492                      0.9794         0.327937
# 549                      1.0000         0.741935
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 110                                    1.0                    0.790323
# 438                                    1.0                    0.790323
# 492                                    1.0                    0.790323
# 549                                    1.0                    0.790323
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 110   1.408730       -0.024914  ...                   303.0
# 438  -0.015467       -0.019963  ...                   303.0
# 492   1.240000        0.041523  ...                   343.0
# 549   1.120640       -0.042341  ...                   303.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 110                 136.446                  136.053                 7.49059
# 438                 136.503                  136.064                 7.49059
# 492                 255.777                  256.044                22.48110
# 549                 133.867                  133.953                 7.50584
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 110                  7.49059                     993.215
# 438                  7.49457                     993.215
# 492                 22.48110                     626.770
# 549                  7.46818                     993.215
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 110                      542.99               1536.20
# 438                      542.99               1536.20
# 492                      268.41                895.18
# 549                      542.99               1536.20
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 110                        4.56296                         4.56296
# 438                        4.56296                         4.56335
# 492                        2.52192                         2.09076
# 549                        4.20531                         3.48553
#
# [4 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 214                      0     O14641     Y27D                O15169
# 215                      0     O14641     Y27D              O15169-2
#
#      Template_sequence_identity  Alignment_score  \
# 214                      0.3562         0.293358
# 215                      0.3562         0.293358
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 214                                 0.9762                     0.97739
# 215                                 0.9762                     0.97739
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 214    2.63456        0.075573  ...                   171.0
# 215    2.63456        0.075573  ...                   171.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 214                 25.6583                  25.3933                 15.7975
# 215                 25.6583                  25.3933                 15.7975
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 214                  15.7971                     324.945
# 215                  15.7971                     324.945
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 214                     208.005                532.95
# 215                     208.005                532.95
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 214                         2.7134                         3.13578
# 215                         2.7134                         3.13578
#
# [2 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 677                      0     O14788    R223A                Q9Y6Q6
# 678                      0     O14788    R223A              Q9Y6Q6-2
#
#      Template_sequence_identity  Alignment_score  \
# 677                      0.9032         0.902219
# 678                      0.9032         0.902219
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 677                                 0.8519                    0.838599
# 678                                 0.8519                    0.838599
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 677    1.41448         0.15614  ...                   236.0
# 678    1.41448         0.15614  ...                   236.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 677                 49.6715                   48.431                 23.9715
# 678                 49.6715                   48.431                 23.9715
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 677                  23.9715                     176.945
# 678                  23.9715                     176.945
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 677                      115.63                292.58
# 678                      115.63                292.58
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 677                        2.94553                         5.48003
# 678                        2.94553                         5.48003
#
# [2 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#     Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 91                      0     O14893    R213D                Q16637
# 92                      0     O14893    R213D              Q16637-2
# 93                      0     O14893    R213D              Q16637-3
# 94                      0     O14893    R213D              Q16637-4
#
#     Template_sequence_identity  Alignment_score  \
# 91                         1.0         0.735178
# 92                         1.0         0.735178
# 93                         1.0         0.735178
# 94                         1.0         0.735178
#
#     Interactor_template_sequence_identity  Interactor_alignment_score  \
# 91                                    1.0                    0.096654
# 92                                    1.0                    0.143646
# 93                                    1.0                    0.101167
# 94                                    1.0                    0.115556
#
#     Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 91    1.53497        0.035172  ...                   212.0
# 92    2.12739        0.035172  ...                   212.0
# 93    2.12739        0.035172  ...                   212.0
# 94    2.12739        0.035172  ...                   212.0
#
#     IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 91                 25.5141                  25.3818                 2.58032
# 92                 28.8231                  28.6950                 2.42473
# 93                 28.8231                  28.6950                 2.42473
# 94                 28.8231                  28.6950                 2.42473
#
#     IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 91                  2.52829                     335.915
# 92                  2.42473                     351.375
# 93                  2.42473                     351.375
# 94                  2.42473                     351.375
#
#     Interface_hydrophilic_area  Interface_total_area  \
# 91                      126.42               462.335
# 92                      138.82               490.190
# 93                      138.82               490.190
# 94                      138.82               490.190
#
#     Interface_contact_distance_wt  Interface_contact_distance_mut
# 91                        3.18915                         3.60593
# 92                        3.82826                         3.05795
# 93                        3.82826                         3.05795
# 94                        3.82826                         3.05795
#
# [4 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 351                      0     O14965    G198L                Q9NQS7
# 352                      0     O14965    G198L              Q9NQS7-2
# 566                      0     O14965    G198A                Q9NQS7
# 567                      0     O14965    G198A              Q9NQS7-2
#
#      Template_sequence_identity  Alignment_score  \
# 351                      0.6832         0.629376
# 352                      0.6832         0.629376
# 566                      0.6832         0.629376
# 567                      0.6832         0.629376
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 351                                    1.0                    0.508475
# 352                                    1.0                    0.508475
# 566                                    1.0                    0.508475
# 567                                    1.0                    0.508475
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 351    3.10809        0.988525  ...                   292.0
# 352    3.53718        0.988525  ...                   292.0
# 566    4.30466        0.987585  ...                   292.0
# 567    2.63340        0.987585  ...                   292.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 351                 80.0940                  81.5688                 2.18852
# 352                 90.0985                  90.5923                 2.32085
# 566                 80.0940                  80.8401                 2.20488
# 567                 90.0985                  90.7917                 2.31252
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 351                  2.18852                     367.490
# 352                  2.32315                     364.175
# 566                  2.20488                     367.490
# 567                  2.31252                     364.175
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 351                     187.965               555.455
# 352                     172.255               536.425
# 566                     187.965               555.455
# 567                     172.255               536.425
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 351                        4.58781                         3.25272
# 352                        4.90139                         3.03241
# 566                        4.53101                         4.05405
# 567                        4.81220                         4.09611
#
# [4 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 111                      0     O14980    F572A                O95149
# 408                      0     O14980    F561A                O95149
# 574                      0     O14980    L525A                O95149
# 581                      0     O14980    I521A                O95149
#
#      Template_sequence_identity  Alignment_score  \
# 111                       0.978         0.968891
# 408                       0.978         0.968891
# 574                       0.978         0.968891
# 581                       0.978         0.968891
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 111                                  0.808                    0.792618
# 408                                  0.808                    0.792618
# 574                                  0.808                    0.792618
# 581                                  0.808                    0.792618
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 111   1.190720        0.996928  ...                  1402.0
# 408   0.909251        0.997012  ...                  1402.0
# 574   0.867247        0.999285  ...                  1402.0
# 581   0.533915        0.996184  ...                  1402.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 111                 246.506                  246.490                 87.4553
# 408                 245.345                  245.171                 87.9905
# 574                 246.647                  246.477                 88.4857
# 581                 246.351                  246.059                 87.9905
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 111                  88.6518                      971.03
# 408                  87.9905                      971.03
# 574                  89.3080                      971.03
# 581                  87.9905                      971.03
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 111                      613.64               1584.68
# 408                      613.64               1584.68
# 574                      613.64               1584.68
# 581                      613.64               1584.68
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 111                        3.37784                         5.99031
# 408                        3.49666                         3.84107
# 574                        3.17623                         2.79942
# 581                        3.57702                         5.01449
#
# [4 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 216                      0     O15085    R868G                P61586
# 224                      0     O15085    R872D                P61586
# 294                      0     O15085    D873N                P61586
# 436                      0     O15085    R867Q                P61586
# 519                      0     O15085    I876M                P61586
#
#      Template_sequence_identity  Alignment_score  \
# 216                       0.302         0.182182
# 224                       0.302         0.182182
# 294                       0.302         0.182182
# 436                       0.302         0.182182
# 519                       0.302         0.182182
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 216                                 0.5575                    0.522563
# 224                                 0.5575                    0.522563
# 294                                 0.5575                    0.522563
# 436                                 0.5575                    0.522563
# 519                                 0.5575                    0.522563
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 216   1.984540        0.358694  ...                   382.0
# 224   0.524656        0.084937  ...                   382.0
# 294  -0.117301        0.851722  ...                   382.0
# 436   0.180869        0.903181  ...                   382.0
# 519   0.205594        0.000396  ...                   382.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 216                 85.4256                  84.6655                 94.0559
# 224                 85.5462                  85.3075                 93.9877
# 294                 85.4543                  85.4346                 94.0235
# 436                 85.4256                  85.3442                 93.9760
# 519                 85.4256                  85.2854                 93.9403
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 216                  94.9611                      595.27
# 224                  93.9877                      595.27
# 294                  94.0235                      595.27
# 436                  93.9760                      595.27
# 519                  93.9403                      595.27
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 216                     304.685               899.955
# 224                     304.685               899.955
# 294                     304.685               899.955
# 436                     304.685               899.955
# 519                     304.685               899.955
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 216                        2.56286                         3.40013
# 224                        3.81389                         4.98073
# 294                        2.87443                         2.77140
# 436                        3.39136                         3.39136
# 519                        3.18619                         3.09639
#
# [5 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 220                      0     O15111     K44M                P25963
# 426                      1     O15111    S176E                P25963
# 449                      0     O15111     K44A                P25963
#
#      Template_sequence_identity  Alignment_score  \
# 220                      0.3095         0.201429
# 426                      0.3095         0.201429
# 449                      0.3095         0.201429
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 220                                 0.4126                     0.28728
# 426                                 0.4126                     0.28728
# 449                                 0.4126                     0.28728
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 220   0.503005        0.996520  ...                   563.0
# 426  -0.262107        0.013557  ...                   563.0
# 449  -0.097966        0.996532  ...                   563.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 220                 231.478                  231.841                 155.166
# 426                 231.715                  233.190                 155.124
# 449                 231.514                  231.178                 155.166
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 220                  155.166                      1540.9
# 426                  155.101                      1540.9
# 449                  155.166                      1540.9
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 220                     807.345               2348.25
# 426                     807.345               2348.25
# 449                     807.345               2348.25
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 220                        2.75538                         3.17265
# 426                        2.87353                         3.53489
# 449                        2.75538                         4.03856
#
# [3 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 218                      1     O43543    V160I              O75771-4
# 219                      1     O43543    V160I              O75771-7
#
#      Template_sequence_identity  Alignment_score  \
# 218                       0.283         0.190818
# 219                       0.283         0.190818
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 218                                 0.2551                    0.267167
# 219                                 0.3478                    0.339285
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 218   0.372561        0.016569  ...                   465.0
# 219  -0.088324        0.011974  ...                   404.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 218                 317.172                  316.825                105.1530
# 219                 349.992                  349.312                 85.9637
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 218                  105.153                      529.86
# 219                   86.034                      424.66
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 218                     239.670                769.53
# 219                     200.115                624.78
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 218                        3.38817                         3.46268
# 219                        3.91026                         3.91026
#
# [2 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 339                      1     O43617     K32Q                O75865
# 340                      1     O43617     K32Q              O75865-2
#
#      Template_sequence_identity  Alignment_score  \
# 339                      0.9688         0.935287
# 340                      0.9688         0.935287
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 339                                 0.9682                    0.957591
# 340                                 0.8889                    0.884115
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 339    4.43837        0.621977  ...                   317.0
# 340    3.33900        0.638891  ...                   331.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 339                 36.0288                  36.0316                 39.4229
# 340                 41.2196                  41.2169                 39.2927
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 339                  39.4229                      582.78
# 340                  39.2927                      537.14
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 339                     244.440               827.220
# 340                     258.055               795.195
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 339                        6.72197                         6.72197
# 340                        6.53941                         6.74431
#
# [2 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 253                      0     O43809    Y160A              Q16630-3
# 254                      0     O43809    Y160A                Q16630
# 255                      0     O43809    Y160A              Q16630-2
# 583                      0     O43809    Y158A              Q16630-3
# 584                      0     O43809    Y158A                Q16630
# 585                      0     O43809    Y158A              Q16630-2
#
#      Template_sequence_identity  Alignment_score  \
# 253                      0.9793         0.980335
# 254                      1.0000         1.000000
# 255                      1.0000         1.000000
# 583                      0.9793         0.980335
# 584                      1.0000         1.000000
# 585                      1.0000         1.000000
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 253                                 0.9892                    0.989740
# 254                                 0.9875                    0.988125
# 255                                 0.9875                    0.988125
# 583                                 0.9892                    0.989740
# 584                                 0.9875                    0.988125
# 585                                 0.9875                    0.988125
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 253   2.162030        0.935388  ...                   286.0
# 254   0.827446        0.945042  ...                   273.0
# 255   0.827446        0.945043  ...                   273.0
# 583   2.155110        0.991339  ...                   286.0
# 584   2.780700        0.991733  ...                   273.0
# 585   2.780700        0.991733  ...                   273.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 253                 42.4183                  42.0285                 23.9128
# 254                 29.8257                  29.1776                 21.9241
# 255                 29.8257                  29.1776                 21.9241
# 583                 42.4174                  42.4162                 23.9128
# 584                 30.2466                  29.5312                 21.9241
# 585                 30.2466                  29.5312                 21.9241
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 253                  23.9128                     174.750
# 254                  21.9241                     195.455
# 255                  21.9241                     195.455
# 583                  23.9128                     174.750
# 584                  21.9241                     195.455
# 585                  21.9241                     195.455
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 253                      123.92                298.67
# 254                      141.69                337.15
# 255                      141.69                337.15
# 583                      123.92                298.67
# 584                      141.69                337.15
# 585                      141.69                337.15
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 253                        2.55760                         6.60322
# 254                        3.85880                         6.56386
# 255                        3.85880                         6.56386
# 583                        2.78388                         4.99487
# 584                        2.98188                         5.49107
# 585                        2.98188                         5.49107
#
# [6 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 173                      0     O95149    N150A                O14980
# 178                      0     O95149      L4A                O14980
# 192                      0     O95149    K144D                O14980
# 599                      0     O95149    Y147A                O14980
# 641                      0     O95149      L8A                O14980
#
#      Template_sequence_identity  Alignment_score  \
# 173                       0.808         0.792618
# 178                       0.808         0.792618
# 192                       0.808         0.792618
# 599                       0.808         0.792618
# 641                       0.808         0.792618
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 173                                  0.978                    0.968891
# 178                                  0.978                    0.968891
# 192                                  0.978                    0.968891
# 599                                  0.978                    0.968891
# 641                                  0.978                    0.968891
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 173   0.757759        0.770836  ...                  1402.0
# 178   0.031647       -0.007047  ...                  1402.0
# 192   0.546290        0.816623  ...                  1402.0
# 599   2.108610       -0.027390  ...                  1402.0
# 641   0.119804        0.893517  ...                  1402.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 173                 87.9905                  88.0826                 246.992
# 178                 88.0168                  88.0261                 246.764
# 192                 87.9905                  88.0669                 246.981
# 599                 88.0448                  87.7386                 246.939
# 641                 88.0025                  87.9523                 246.992
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 173                  246.992                      971.03
# 178                  246.225                      971.03
# 192                  247.047                      971.03
# 599                  246.919                      971.03
# 641                  246.992                      971.03
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 173                      613.64               1584.68
# 178                      613.64               1584.68
# 192                      613.64               1584.68
# 599                      613.64               1584.68
# 641                      613.64               1584.68
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 173                        4.95049                         6.17756
# 178                        4.21747                         5.77104
# 192                        2.80008                         3.59042
# 599                        3.14783                         3.45619
# 641                        3.17623                         3.17623
#
# [5 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 347                      1     O95405    A797P                P84022
# 348                      1     O95405    A797P              P84022-4
# 349                      1     O95405    A797P              P84022-2
# 350                      1     O95405    A797P              P84022-3
#
#      Template_sequence_identity  Alignment_score  \
# 347                         1.0         0.911111
# 348                         1.0         0.911111
# 349                         1.0         0.911111
# 350                         1.0         0.911111
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 347                                 0.9742                    0.918665
# 348                                 0.9742                    0.918665
# 349                                 0.9742                    0.918665
# 350                                 0.9742                    0.918665
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 347   0.576780       -0.104322  ...                   235.0
# 348   0.576780       -0.104322  ...                   235.0
# 349   0.351317       -0.104322  ...                   235.0
# 350   0.351317       -0.104322  ...                   235.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 347                 5.71379                  6.65198                 50.9830
# 348                 5.71379                  6.65198                 50.9830
# 349                13.50000                 22.30220                 52.3441
# 350                13.50000                 22.30220                 52.3441
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 347                  50.9830                     765.595
# 348                  50.9830                     765.595
# 349                  52.3441                     700.740
# 350                  52.3441                     700.740
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 347                     235.955               1001.55
# 348                     235.955               1001.55
# 349                     230.895                931.63
# 350                     230.895                931.63
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 347                        2.83808                         3.00253
# 348                        2.83808                         3.00253
# 349                        3.62969                         3.85293
# 350                        3.62969                         3.85293
#
# [4 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 479                      1     P00492     P38S                Q9NRG1
# 480                      1     P00492     P38S              Q9NRG1-2
#
#      Template_sequence_identity  Alignment_score  \
# 479                      0.9907         0.972978
# 480                      0.9907         0.972978
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 479                                 0.6777                    0.650644
# 480                                 0.6550                    0.605025
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 479   2.374050             0.0  ...                   433.0
# 480   0.479064             0.0  ...                   398.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 479                 55.8168                  55.8453                 55.3707
# 480                 40.9024                  40.9193                 58.4174
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 479                  55.3707                     325.425
# 480                  58.4174                     384.710
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 479                     218.695               544.120
# 480                     251.500               636.205
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 479                        3.38398                         3.38398
# 480                        3.08944                         3.08944
#
# [2 rows x 62 columns]
# 2021-11-13 15:40:10 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 1                        0     P01116     Y40C                P50749
# 657                      0     P01116     E37G                P50749
#
#      Template_sequence_identity  Alignment_score  \
# 1                        0.9277         0.931315
# 657                      0.9277         0.931315
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 1                                   0.3553                      0.1725
# 657                                 0.3553                      0.1725
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 1      2.07695        0.998749  ...                   329.0
# 657    2.47058        0.999487  ...                   329.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 1                   47.6177                  47.2116                 70.2902
# 657                 45.0313                  44.5169                 70.2449
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 1                    70.2461                      464.47
# 657                  70.2449                      464.47
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 1                        400.03               864.505
# 657                      400.03               864.505
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 1                          3.07827                         3.59123
# 657                        2.63614                         3.21798
#
# [2 rows x 62 columns]
# 2021-11-13 15:40:11 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 229                      1     P01133    L996V              P00533-3
# 230                      1     P01133    H980Y                P00533
# 231                      1     P01133    H980Y              P00533-2
# 232                      1     P01133    H980Y              P00533-3
# 233                      1     P01133    H980Y              P00533-3
# 234                      1     P01133    H980Y              P00533-4
# 356                      1     P01133    D973Y                P00533
# 357                      1     P01133    D973Y              P00533-2
# 358                      1     P01133    D973Y              P00533-4
# 632                      1     P01133    K998R              P00533-3
# 633                      1     P01133    K998R              P00533-3
# 682                      1     P01133    K998S              P00533-3
# 683                      1     P01133    K998S              P00533-3
# 694                      1     P01133    M991S              P00533-3
#
#      Template_sequence_identity  Alignment_score  \
# 229                       1.000         0.401961
# 230                       1.000         0.401961
# 231                       1.000         0.401961
# 232                       1.000         0.401961
# 233                       0.381         0.157510
# 234                       1.000         0.401961
# 356                       1.000         0.401961
# 357                       1.000         0.401961
# 358                       1.000         0.401961
# 632                       1.000         0.401961
# 633                       0.381         0.157510
# 682                       1.000         0.401961
# 683                       0.381         0.157510
# 694                       1.000         0.401961
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 229                                   1.00                    0.986842
# 230                                   1.00                    0.986842
# 231                                   1.00                    0.986842
# 232                                   1.00                    0.986842
# 233                                   0.32                    0.174671
# 234                                   1.00                    0.986842
# 356                                   1.00                    0.986842
# 357                                   1.00                    0.986842
# 358                                   1.00                    0.986842
# 632                                   1.00                    0.986842
# 633                                   0.32                    0.174671
# 682                                   1.00                    0.986842
# 683                                   0.32                    0.174671
# 694                                   1.00                    0.986842
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 229  -1.380230        0.059158  ...                   191.0
# 230   0.186870       -0.007207  ...                   193.0
# 231   0.186870       -0.007207  ...                   193.0
# 232   1.396510       -0.006417  ...                   191.0
# 233   0.499867        0.001248  ...                   195.0
# 234   0.186870       -0.007207  ...                   193.0
# 356  -2.461130        0.023319  ...                   193.0
# 357  -2.461130        0.023319  ...                   193.0
# 358  -2.461130        0.023319  ...                   193.0
# 632   0.128625       -0.006449  ...                   191.0
# 633  -0.750536       -0.007113  ...                   195.0
# 682  -0.856695       -0.018504  ...                   191.0
# 683  -0.949288       -0.047322  ...                   195.0
# 694   2.051810       -0.147448  ...                   191.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 229                 10.9840                 12.33610                 45.2700
# 230                 14.3091                 15.40620                130.7440
# 231                 14.3091                 15.40620                130.7440
# 232                 11.5042                 11.56680                 45.2772
# 233                 21.1891                 21.53900                 81.9433
# 234                 14.3091                 15.40620                130.7440
# 356                 14.3091                 14.39100                130.7440
# 357                 14.3091                 14.39100                130.7440
# 358                 14.3091                 14.39100                130.7440
# 632                 11.3203                 11.56860                 45.2434
# 633                 20.4066                 20.37430                 81.9433
# 682                 11.5747                 11.67310                 45.2772
# 683                 20.1672                 20.15790                 81.9433
# 694                 10.2202                  9.99991                 45.2772
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 229                  45.2671                     334.260
# 230                 130.7440                     127.995
# 231                 130.7440                     127.995
# 232                  45.2772                     334.260
# 233                  81.9433                     151.135
# 234                 130.7440                     127.995
# 356                 130.7440                     127.995
# 357                 130.7440                     127.995
# 358                 130.7440                     127.995
# 632                  45.2359                     334.260
# 633                  81.9433                     151.135
# 682                  45.2458                     334.260
# 683                  81.9433                     151.135
# 694                  45.2772                     334.260
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 229                     139.885               474.150
# 230                     138.730               266.725
# 231                     138.730               266.725
# 232                     139.885               474.150
# 233                     167.840               318.975
# 234                     138.730               266.725
# 356                     138.730               266.725
# 357                     138.730               266.725
# 358                     138.730               266.725
# 632                     139.885               474.150
# 633                     167.840               318.975
# 682                     139.885               474.150
# 683                     167.840               318.975
# 694                     139.885               474.150
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 229                        3.44953                         4.56649
# 230                        2.49767                         2.49767
# 231                        2.49767                         2.49767
# 232                        6.15699                         3.40602
# 233                        3.54995                         3.53976
# 234                        2.49767                         2.49767
# 356                        4.57272                         5.32303
# 357                        4.57272                         5.32303
# 358                        4.57272                         5.32303
# 632                        2.61137                         2.81380
# 633                        4.84132                         4.84132
# 682                        2.61137                         4.29748
# 683                        4.43505                         4.46116
# 694                        3.79967                         6.09881
#
# [14 rows x 62 columns]
# 2021-11-13 15:40:11 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 475                      1     P01270     H63A                Q03431
# 542                      1     P01270     K58L                Q03431
# 647                      1     P01270     V62A                Q03431
#
#      Template_sequence_identity  Alignment_score  \
# 475                         1.0         0.229885
# 542                         1.0         0.229885
# 647                         1.0         0.229885
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 475                                 0.9861                    0.617819
# 542                                 0.9861                    0.617819
# 647                                 0.9861                    0.617819
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 475    1.50652       -0.041066  ...                   132.0
# 542    2.30970       -0.027639  ...                   132.0
# 647    1.34406        0.009307  ...                   132.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 475                 2.78629                  2.70562                 26.6864
# 542                 2.78629                  2.83554                 26.6826
# 647                 2.78629                  1.78149                 26.6826
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 475                  26.6864                     329.955
# 542                  26.6864                     329.955
# 647                  26.6826                     329.955
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 475                     156.225                486.19
# 542                     156.225                486.19
# 647                     156.225                486.19
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 475                        3.46558                         3.46558
# 542                        3.82571                         3.61298
# 647                        3.17822                         3.67540
#
# [3 rows x 62 columns]
# 2021-11-13 15:40:11 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 157                      0     P04637     F19A                Q09472
# 197                      0     P04637     L25A                Q09472
# 223                      0     P04637     L22A                Q09472
#
#      Template_sequence_identity  Alignment_score  \
# 157                         1.0         0.639344
# 197                         1.0         0.639344
# 223                         1.0         0.639344
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 157                                 0.9556                    0.736785
# 197                                 0.9556                    0.736785
# 223                                 0.9556                    0.736785
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 157   2.710890       -0.044797  ...                   129.0
# ...
# 537                  87.3250                     524.985
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 102                      258.98                783.96
# 493                      258.98                783.96
# 537                      258.98                783.96
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 102                        3.07787                         4.39864
# 493                        2.46202                         2.98422
# 537                        2.78517                         2.78517
#
# [3 rows x 62 columns]
# 2021-11-13 15:40:15 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 166                      1     Q9Y248    L150S                Q9BRT9
# 421                      1     Q9Y248     D24G                Q9BRT9
# 488                      1     Q9Y248     I26T                Q9BRT9
#
#      Template_sequence_identity  Alignment_score  \
# 166                         1.0         0.935135
# 421                         1.0         0.935135
# 488                         1.0         0.935135
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 166                                    1.0                    0.877301
# 421                                    1.0                    0.877301
# 488                                    1.0                    0.877301
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 166   0.573105        0.020977  ...                   316.0
# 421   0.983328        0.032874  ...                   316.0
# 488   0.663944        0.001071  ...                   316.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 166                 55.8804                  55.8807                 31.8454
# 421                 56.0477                  56.0154                 31.8454
# 488                 54.5234                  54.5692                 31.8454
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 166                  31.8454                      459.07
# 421                  31.8454                      459.07
# 488                  31.8454                      459.07
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 166                     220.045               679.115
# 421                     220.045               679.115
# 488                     220.045               679.115
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 166                        4.37727                         5.29196
# 421                        3.81928                         3.81928
# 488                        2.42618                         3.57348
#
# [3 rows x 62 columns]
# 2021-11-13 15:40:15 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 413                      0     Q9Y294     D37A                P54198
# 414                      0     Q9Y294     D37A              P54198-2
#
#      Template_sequence_identity  Alignment_score  \
# 413                         1.0         0.987179
# 414                         1.0         0.987179
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 413                                    1.0                        0.64
# 414                                    1.0                        0.64
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 413    3.18837        0.982855  ...                   170.0
# 414    2.91452        0.982855  ...                   170.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 413                 30.9246                  30.8438                 1.78374
# 414                 35.3525                  35.3150                 1.61542
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 413                  1.70537                     194.670
# 414                  1.76593                     189.125
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 413                     160.885               355.555
# 414                     156.800               345.930
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 413                        2.75194                         4.70142
# 414                        3.15051                         6.21002
#
# [2 rows x 62 columns]
# 2021-11-13 15:40:15 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 261                      0     Q9Y2M5    L148A                Q13618
# 393                      0     Q9Y2M5    I111A                Q13618
# 603                      0     Q9Y2M5    C146A              Q13618-2
# 604                      0     Q9Y2M5    C146A              Q13618-3
# 605                      0     Q9Y2M5    C146A                Q13618
#
#      Template_sequence_identity  Alignment_score  \
# 261                      0.5104         0.405917
# 393                      0.5104         0.405917
# 603                      0.5104         0.405917
# 604                      0.5104         0.405917
# 605                      0.5104         0.405917
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 261                                 0.9689                    0.447319
# 393                                 0.9689                    0.447319
# 603                                 0.9689                    0.461749
# 604                                 0.9622                    0.399644
# 605                                 0.9689                    0.447319
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 261   0.836808        0.992672  ...                   572.0
# 393   1.067610        0.901846  ...                   572.0
# 603   0.121677        0.934410  ...                   572.0
# 604   1.756200        0.945901  ...                   531.0
# 605  -0.089393        0.934410  ...                   572.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 261                 92.8239                  92.7128                102.4320
# 393                 92.8191                  92.5366                102.4320
# 603                 74.0004                  73.9810                 85.8306
# 604                 87.6941                  87.9348                 76.1058
# 605                 91.0450                  90.8153                102.4320
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 261                 102.4320                     742.255
# 393                 102.4320                     742.255
# 603                  85.8306                     751.610
# 604                  75.9470                     392.760
# 605                 102.4320                     742.255
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 261                      478.10               1220.36
# 393                      478.10               1220.36
# 603                      543.83               1295.44
# 604                      213.35                606.11
# 605                      478.10               1220.36
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 261                        4.79710                         4.79710
# 393                        3.82218                         3.82218
# 603                        3.32078                         3.48351
# 604                        3.77001                         4.05464
# 605                        3.37813                         3.49180
#
# [5 rows x 62 columns]
# 2021-11-13 15:40:15 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 24                       0     Q9Y4K3     L74E                P61088
# 113                      0     Q9Y4K3     L74R                P61088
# 195                      0     Q9Y4K3     L74H                P61088
# 466                      0     Q9Y4K3     I72F                P61088
# 485                      0     Q9Y4K3     L74K                P61088
# 532                      0     Q9Y4K3     I72K                P61088
# 696                      0     Q9Y4K3     I72D                P61088
# 717                      0     Q9Y4K3     D57K                P61088
#
#      Template_sequence_identity  Alignment_score  \
# 24                          1.0              1.0
# 113                         1.0              1.0
# 195                         1.0              1.0
# 466                         1.0              1.0
# 485                         1.0              1.0
# 532                         1.0              1.0
# 696                         1.0              1.0
# 717                         1.0              1.0
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 24                                     1.0                    0.973684
# 113                                    1.0                    0.973684
# 195                                    1.0                    0.973684
# 466                                    1.0                    0.973684
# 485                                    1.0                    0.973684
# 532                                    1.0                    0.973684
# 696                                    1.0                    0.973684
# 717                                    1.0                    0.973684
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 24    2.474390        0.097301  ...                   245.0
# 113   2.092150        0.015000  ...                   245.0
# 195   1.507930        0.072926  ...                   245.0
# 466   1.312960        0.762512  ...                   245.0
# 485   2.117250       -0.157658  ...                   245.0
# 532   1.307230        0.762742  ...                   245.0
# 696   1.552900        0.766873  ...                   245.0
# 717   0.949657        0.019166  ...                   245.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 24                  19.3675                  19.3084                 29.5865
# 113                 19.3620                  19.3677                 29.5815
# 195                 19.3684                  19.3526                 29.5865
# 466                 19.4180                  19.2552                 28.8901
# 485                 19.3620                  19.2765                 29.5815
# 532                 19.3700                  19.1598                 28.8901
# 696                 19.3667                  19.2456                 29.5815
# 717                 19.2899                  19.3773                 28.9327
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 24                   29.6190                      248.92
# 113                  29.5815                      248.92
# 195                  29.5865                      248.92
# 466                  28.8901                      248.92
# 485                  29.5815                      248.92
# 532                  28.8901                      248.92
# 696                  29.5815                      248.92
# 717                  28.9327                      248.92
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 24                      161.845                410.76
# 113                     161.845                410.76
# 195                     161.845                410.76
# 466                     161.845                410.76
# 485                     161.845                410.76
# 532                     161.845                410.76
# 696                     161.845                410.76
# 717                     161.845                410.76
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 24                         3.86840                         3.97838
# 113                        2.91983                         2.91983
# 195                        3.74029                         3.36396
# 466                        3.27070                         3.27070
# 485                        2.91983                         2.91983
# 532                        3.27070                         3.27070
# 696                        3.31536                         3.31536
# 717                        2.93789                         3.76901
#
# [8 rows x 62 columns]
# 2021-11-13 15:40:15 | CRITICAL | helpers.helpers_analysis.justify_sampling | corr_score_values=[]
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 402                      0     Q9Y570    S156A                P67775
# 403                      0     Q9Y570    S156A              P67775-2
# 546                      0     Q9Y570    H349A                P67775
# 660                      0     Q9Y570    S156T                P67775
# 661                      0     Q9Y570    S156T              P67775-2
#
#      Template_sequence_identity  Alignment_score  \
# 402                       0.861          0.86795
# 403                       0.861          0.86795
# 546                       0.861          0.86795
# 660                       0.861          0.86795
# 661                       0.861          0.86795
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 402                                 0.9671                     0.95307
# 403                                 0.7599                     0.75677
# 546                                 0.9671                     0.95307
# 660                                 0.9671                     0.95307
# 661                                 0.7599                     0.75677
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 402   0.448956        0.998590  ...                   635.0
# 403   1.610100        0.998532  ...                   581.0
# 546   4.784400        0.997325  ...                   635.0
# 660  -0.165374        0.998695  ...                   635.0
# 661   0.642228        0.998642  ...                   581.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 402                 522.291                  521.956                 106.550
# 403                 284.968                  284.906                 117.472
# 546                 521.335                  520.883                 106.550
# 660                 522.291                  528.200                 106.550
# 661                 284.968                  287.635                 117.472
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 402                  106.550                      643.86
# 403                  117.472                      518.68
# 546                  106.550                      643.86
# 660                  106.550                      643.86
# 661                  117.472                      518.68
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 402                     427.395              1071.240
# 403                     226.285               744.965
# 546                     427.395              1071.240
# 660                     427.395              1071.240
# 661                     226.285               744.965
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 402                        2.73755                         2.73755
# 403                        2.25568                         2.73882
# 546                        2.68422                         3.39038
# 660                        2.73755                         2.72440
# 661                        2.25568                         1.79600
#
# [5 rows x 62 columns]

# %%
mutation_justifier.export_data("dev/justify_sampling/mutation_justifier")
# Out:
# 2021-11-13 15:40:40 | INFO     | helpers.helpers_analysis.justify_sampling | dev/justify_sampling/mutation_justifier_2021-11-13.csv is exported successfully.

# %%
mutation_justifier.unique_proteins_corr_data["PEARSON_CORR"].value_counts()
# Out:
# HAS ONLY ONE INTERACTOR ACROSS ALL MUTATIONS    90
# NOT APPLICABLE                                  39
# 1.0                                              8
# 0.99                                             6
# 0.98                                             5
# 0.84                                             2
# 0.94                                             2
# 0.97                                             2
# 0.46                                             1
# 0.57                                             1
# 0.63                                             1
# 0.48                                             1
# 0.86                                             1
# 0.52                                             1
# 0.7                                              1
# 0.62                                             1
# 0.81                                             1
# 0.93                                             1
# Name: PEARSON_CORR, dtype: int64

# %%
mutation_justifier.unique_proteins_corr_data[
    (mutation_justifier.unique_proteins_corr_data["PEARSON_CORR"] != "HAS ONLY ONE INTERACTOR ACROSS ALL MUTATIONS") &
    (mutation_justifier.unique_proteins_corr_data["PEARSON_CORR"] != "NOT APPLICABLE")
].sample()
# Out:
#    PROTEIN PEARSON_CORR
# 70  P55957         0.94

# %%
from helpers.helpers_analysis.justify_sampling import (
    get_corr_values, get_entries_with_protein
)

# %%
get_entries_with_protein("P55957", mutation_justifier.training_data)
# Out:
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 51                       0     P55957     D95A                Q07817
# 327                      0     P55957     G94A                Q92843
# 411                      0     P55957     D95A                Q92843
# 700                      0     P55957     G94A                Q07817
#
#      Template_sequence_identity  Alignment_score  \
# 51                         0.95         0.097692
# 327                        0.95         0.097692
# 411                        0.95         0.097692
# 700                        0.95         0.097692
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 51                                  0.4256                    0.442962
# 327                                 0.9882                    0.870955
# 411                                 0.9882                    0.870955
# 700                                 0.4256                    0.442962
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 51     3.92915       -0.030647  ...                   220.0
# 327    2.19402       -0.096899  ...                   190.0
# 411    2.20332       -0.081687  ...                   190.0
# 700    2.63357       -0.044742  ...                   220.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 51                  5.85240                  5.75488                273.6070
# 327                 5.17364                  6.10529                 36.6223
# 411                 5.17364                  5.15763                 36.7363
# 700                 5.75607                  6.13871                273.3810
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 51                  273.6070                     444.380
# 327                  36.6223                     496.245
# 411                  36.8067                     496.245
# 700                 273.3810                     444.380
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 51                       282.86                727.24
# 327                      272.92                769.17
# 411                      272.92                769.17
# 700                      282.86                727.24
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 51                         2.77456                         3.35569
# 327                        4.62744                         4.62744
# 411                        2.89294                         3.44835
# 700                        4.60709                         4.60709
#
# [4 rows x 62 columns]

# %%
get_corr_values(get_entries_with_protein("P55957", mutation_justifier.training_data))
# Out:
# 2021-11-13 15:55:42 | DEBUG    | helpers.helpers_analysis.justify_sampling | skip (51, 700)
# 2021-11-13 15:55:42 | DEBUG    | helpers.helpers_analysis.justify_sampling | skip (327, 411)
# 2021-11-13 15:55:42 | DEBUG    | helpers.helpers_analysis.justify_sampling | len(corr_score_values)=4
# 0.94

# %%
get_entries_with_protein("Q9Y570", mutation_justifier.training_data)
# Out:
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 402                      0     Q9Y570    S156A                P67775
# 403                      0     Q9Y570    S156A              P67775-2
# 546                      0     Q9Y570    H349A                P67775
# 660                      0     Q9Y570    S156T                P67775
# 661                      0     Q9Y570    S156T              P67775-2
#
#      Template_sequence_identity  Alignment_score  \
# 402                       0.861          0.86795
# 403                       0.861          0.86795
# 546                       0.861          0.86795
# 660                       0.861          0.86795
# 661                       0.861          0.86795
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 402                                 0.9671                     0.95307
# 403                                 0.7599                     0.75677
# 546                                 0.9671                     0.95307
# 660                                 0.9671                     0.95307
# 661                                 0.7599                     0.75677
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 402   0.448956        0.998590  ...                   635.0
# 403   1.610100        0.998532  ...                   581.0
# 546   4.784400        0.997325  ...                   635.0
# 660  -0.165374        0.998695  ...                   635.0
# 661   0.642228        0.998642  ...                   581.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 402                 522.291                  521.956                 106.550
# 403                 284.968                  284.906                 117.472
# 546                 521.335                  520.883                 106.550
# 660                 522.291                  528.200                 106.550
# 661                 284.968                  287.635                 117.472
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 402                  106.550                      643.86
# 403                  117.472                      518.68
# 546                  106.550                      643.86
# 660                  106.550                      643.86
# 661                  117.472                      518.68
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 402                     427.395              1071.240
# 403                     226.285               744.965
# 546                     427.395              1071.240
# 660                     427.395              1071.240
# 661                     226.285               744.965
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 402                        2.73755                         2.73755
# 403                        2.25568                         2.73882
# 546                        2.68422                         3.39038
# 660                        2.73755                         2.72440
# 661                        2.25568                         1.79600
#
# [5 rows x 62 columns]

# %%
get_entries_with_protein("O95149", mutation_justifier.training_data)
# Out:
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 173                      0     O95149    N150A                O14980
# 178                      0     O95149      L4A                O14980
# 192                      0     O95149    K144D                O14980
# 599                      0     O95149    Y147A                O14980
# 641                      0     O95149      L8A                O14980
#
#      Template_sequence_identity  Alignment_score  \
# 173                       0.808         0.792618
# 178                       0.808         0.792618
# 192                       0.808         0.792618
# 599                       0.808         0.792618
# 641                       0.808         0.792618
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 173                                  0.978                    0.968891
# 178                                  0.978                    0.968891
# 192                                  0.978                    0.968891
# 599                                  0.978                    0.968891
# 641                                  0.978                    0.968891
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 173   0.757759        0.770836  ...                  1402.0
# 178   0.031647       -0.007047  ...                  1402.0
# 192   0.546290        0.816623  ...                  1402.0
# 599   2.108610       -0.027390  ...                  1402.0
# 641   0.119804        0.893517  ...                  1402.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 173                 87.9905                  88.0826                 246.992
# 178                 88.0168                  88.0261                 246.764
# 192                 87.9905                  88.0669                 246.981
# 599                 88.0448                  87.7386                 246.939
# 641                 88.0025                  87.9523                 246.992
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 173                  246.992                      971.03
# 178                  246.225                      971.03
# 192                  247.047                      971.03
# 599                  246.919                      971.03
# 641                  246.992                      971.03
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 173                      613.64               1584.68
# 178                      613.64               1584.68
# 192                      613.64               1584.68
# 599                      613.64               1584.68
# 641                      613.64               1584.68
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 173                        4.95049                         6.17756
# 178                        4.21747                         5.77104
# 192                        2.80008                         3.59042
# 599                        3.14783                         3.45619
# 641                        3.17623                         3.17623
#
# [5 rows x 62 columns]

# %%
mutation_justifier.unique_proteins_corr_data[
    mutation_justifier.unique_proteins_corr_data["PROTEIN"] == "O00311"
]
# Out:
#   PROTEIN                                  PEARSON_CORR
# 2  O00311  HAS ONLY ONE INTERACTOR ACROSS ALL MUTATIONS

# %%
get_entries_with_protein("O00311", mutation_justifier.training_data)
# Out:
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 110                      1     O00311     I99T                Q9UBU7
# 438                      1     O00311     I99L                Q9UBU7
# 492                      1     O00311    K416T                Q9UBU7
# 549                      1     O00311    Q106R                Q9UBU7
#
#      Template_sequence_identity  Alignment_score  \
# 110                      1.0000         0.741935
# 438                      1.0000         0.741935
# 492                      0.9794         0.327937
# 549                      1.0000         0.741935
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 110                                    1.0                    0.790323
# 438                                    1.0                    0.790323
# 492                                    1.0                    0.790323
# 549                                    1.0                    0.790323
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 110   1.408730       -0.024914  ...                   303.0
# 438  -0.015467       -0.019963  ...                   303.0
# 492   1.240000        0.041523  ...                   343.0
# 549   1.120640       -0.042341  ...                   303.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 110                 136.446                  136.053                 7.49059
# 438                 136.503                  136.064                 7.49059
# 492                 255.777                  256.044                22.48110
# 549                 133.867                  133.953                 7.50584
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 110                  7.49059                     993.215
# 438                  7.49457                     993.215
# 492                 22.48110                     626.770
# 549                  7.46818                     993.215
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 110                      542.99               1536.20
# 438                      542.99               1536.20
# 492                      268.41                895.18
# 549                      542.99               1536.20
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 110                        4.56296                         4.56296
# 438                        4.56296                         4.56335
# 492                        2.52192                         2.09076
# 549                        4.20531                         3.48553
#
# [4 rows x 62 columns]

# %%
get_corr_values()
