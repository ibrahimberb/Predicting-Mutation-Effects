# %% [markdown]
# # Justifying Sampling

# %%
import pandas as pd
from scipy.stats.stats import pearsonr

# %%
training_data = pd.read_csv("../../processed_data_740.csv")

# %%
training_data.head()
# Out:
#    Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 0                      0     Q9BPZ3    F118A                P11940
# 1                      0     P01116     Y40C                P50749
# 2                      0     Q96QK1    F534D                Q9UBQ0
# 3                      0     Q96QK1    F534D              Q9UBQ0-2
# 4                      0   O43521-3     G66A                Q07812
#
#    Template_sequence_identity  Alignment_score  \
# 0                      1.0000         1.000000
# 1                      0.9277         0.931315
# 2                      1.0000         0.360743
# 3                      1.0000         0.360743
# 4                      1.0000         0.714286
#
#    Interactor_template_sequence_identity  Interactor_alignment_score  \
# 0                                 1.0000                    0.968750
# 1                                 0.3553                    0.172500
# 2                                 1.0000                    0.994505
# 3                                 1.0000                    0.973118
# 4                                 0.3007                    0.222028
#
#    Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 0   1.219700       -0.092273  ...                   118.0
# 1   2.076950        0.998749  ...                   329.0
# 2   2.695710        0.288297  ...                   453.0
# 3   2.695710        0.288297  ...                   453.0
# 4   0.683334       -0.051025  ...                   202.0
#
#    IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 0                 5.30636                  3.79101                 52.4675
# 1                47.61770                 47.21160                 70.2902
# 2                68.21080                 68.19710                 59.2321
# 3                68.21080                 68.19710                 59.2321
# 4                 3.74828                  3.76142                 41.5937
#
#    IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 0                  52.4675                     427.775
# 1                  70.2461                     464.470
# 2                  59.1774                     510.690
# 3                  59.1774                     510.690
# 4                  41.5937                     405.510
#
#    Interface_hydrophilic_area  Interface_total_area  \
# 0                     194.715               622.495
# 1                     400.030               864.505
# 2                     298.820               809.510
# 3                     298.820               809.510
# 4                     273.740               679.245
#
#    Interface_contact_distance_wt  Interface_contact_distance_mut
# 0                        3.35293                         3.35293
# 1                        3.07827                         3.59123
# 2                        3.03938                         3.24435
# 3                        3.03938                         3.24435
# 4                        3.37301                         3.22505
#
# [5 rows x 62 columns]

# %%
def convert_isoform(protein_param):
    return protein_param.split('-')[0]

# %%
# training_data["Interactor_UniProt_ID"] = training_data["Interactor_UniProt_ID"].apply(lambda x: convert_isoform(x))

# %%
training_data.head()
# Out:
#    Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 0                      0     Q9BPZ3    F118A                P11940
# 1                      0     P01116     Y40C                P50749
# 2                      0     Q96QK1    F534D                Q9UBQ0
# 3                      0     Q96QK1    F534D              Q9UBQ0-2
# 4                      0   O43521-3     G66A                Q07812
#
#    Template_sequence_identity  Alignment_score  \
# 0                      1.0000         1.000000
# 1                      0.9277         0.931315
# 2                      1.0000         0.360743
# 3                      1.0000         0.360743
# 4                      1.0000         0.714286
#
#    Interactor_template_sequence_identity  Interactor_alignment_score  \
# 0                                 1.0000                    0.968750
# 1                                 0.3553                    0.172500
# 2                                 1.0000                    0.994505
# 3                                 1.0000                    0.973118
# 4                                 0.3007                    0.222028
#
#    Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 0   1.219700       -0.092273  ...                   118.0
# 1   2.076950        0.998749  ...                   329.0
# 2   2.695710        0.288297  ...                   453.0
# 3   2.695710        0.288297  ...                   453.0
# 4   0.683334       -0.051025  ...                   202.0
#
#    IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 0                 5.30636                  3.79101                 52.4675
# 1                47.61770                 47.21160                 70.2902
# 2                68.21080                 68.19710                 59.2321
# 3                68.21080                 68.19710                 59.2321
# 4                 3.74828                  3.76142                 41.5937
#
#    IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 0                  52.4675                     427.775
# 1                  70.2461                     464.470
# 2                  59.1774                     510.690
# 3                  59.1774                     510.690
# 4                  41.5937                     405.510
#
#    Interface_hydrophilic_area  Interface_total_area  \
# 0                     194.715               622.495
# 1                     400.030               864.505
# 2                     298.820               809.510
# 3                     298.820               809.510
# 4                     273.740               679.245
#
#    Interface_contact_distance_wt  Interface_contact_distance_mut
# 0                        3.35293                         3.35293
# 1                        3.07827                         3.59123
# 2                        3.03938                         3.24435
# 3                        3.03938                         3.24435
# 4                        3.37301                         3.22505
#
# [5 rows x 62 columns]

# %%
def get_entries_with_pair(protein_param, interactor_param, data):
    query_data = data[
        (data["UniProt_ID"] == protein_param) &
        (data["Interactor_UniProt_ID"] == interactor_param)
    ].copy()
    
    return query_data

# %%
get_entries_with_pair('Q96QK1', 'Q9UBQ0', training_data)
# Out:
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 2                        0     Q96QK1    F534D                Q9UBQ0
# 96                       0     Q96QK1    N725A                Q9UBQ0
# 124                      0     Q96QK1    Q586A                Q9UBQ0
# 127                      0     Q96QK1    R582D                Q9UBQ0
# 138                      0     Q96QK1    Y729A                Q9UBQ0
# 168                      0     Q96QK1    H675D                Q9UBQ0
# 202                      0     Q96QK1    F541D                Q9UBQ0
# 246                      0     Q96QK1    T629D                Q9UBQ0
# 441                      0     Q96QK1    R637D                Q9UBQ0
# 736                      0     Q96QK1    L589D                Q9UBQ0
#
#      Template_sequence_identity  Alignment_score  \
# 2                           1.0         0.360743
# 96                          1.0         0.360743
# 124                         1.0         0.360743
# 127                         1.0         0.360743
# 138                         1.0         0.360743
# 168                         1.0         0.360743
# 202                         1.0         0.360743
# 246                         1.0         0.360743
# 441                         1.0         0.360743
# 736                         1.0         0.360743
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 2                                      1.0                    0.994505
# 96                                     1.0                    0.994505
# 124                                    1.0                    0.994505
# 127                                    1.0                    0.994505
# 138                                    1.0                    0.994505
# 168                                    1.0                    0.994505
# 202                                    1.0                    0.994505
# 246                                    1.0                    0.994505
# 441                                    1.0                    0.994505
# 736                                    1.0                    0.994505
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 2      2.69571        0.288297  ...                   453.0
# 96     2.83600        0.916078  ...                   453.0
# 124    1.69728        0.836538  ...                   453.0
# 127    1.89800        0.985430  ...                   453.0
# 138    2.41611        0.778950  ...                   453.0
# 168    2.71646        0.974218  ...                   453.0
# 202    1.54515        0.002166  ...                   453.0
# 246    1.25219        0.403159  ...                   453.0
# 441    1.74335        0.012581  ...                   453.0
# 736    2.17879        0.803401  ...                   453.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 2                   68.2108                  68.1971                 59.2321
# 96                  68.3251                  68.3288                 59.2581
# 124                 68.2107                  68.2108                 59.2629
# 127                 68.2989                  68.2722                 59.2629
# 138                 67.6606                  67.5852                 58.0716
# 168                 67.7408                  67.6907                 57.9430
# 202                 68.3913                  68.2875                 59.2629
# 246                 68.3429                  68.2148                 59.2629
# 441                 66.7132                  66.4301                 58.0716
# 736                 68.1308                  68.1233                 59.2629
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 2                    59.1774                      510.69
# 96                   59.2714                      510.69
# 124                  59.2629                      510.69
# 127                  59.1671                      510.69
# 138                  58.0429                      510.69
# 168                  58.1219                      510.69
# 202                  59.2629                      510.69
# 246                  59.2629                      510.69
# 441                  58.0716                      510.69
# 736                  59.2629                      510.69
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 2                        298.82                809.51
# 96                       298.82                809.51
# 124                      298.82                809.51
# 127                      298.82                809.51
# 138                      298.82                809.51
# 168                      298.82                809.51
# 202                      298.82                809.51
# 246                      298.82                809.51
# 441                      298.82                809.51
# 736                      298.82                809.51
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 2                          3.03938                         3.24435
# 96                         2.86529                         3.62384
# 124                        2.93412                         4.81473
# 127                        2.90949                         3.61897
# 138                        2.60257                         3.64797
# 168                        3.54986                         3.68059
# 202                        3.46911                         4.25479
# 246                        4.36339                         4.34314
# 441                        3.93484                         3.09306
# 736                        3.45879                         3.26826
#
# [10 rows x 62 columns]

# %%
def is_same_interactor(data):
    unique_interactors = data["Interactor_UniProt_ID"].unique()
    unique_interactors = set(map(convert_isoform, unique_interactors))
    return len(unique_interactors) == 1

# %%
unique_pairs = sorted(set(zip(training_data["UniProt_ID"], training_data["Interactor_UniProt_ID"])))
unique_pairs[:5]
# Out:
# [('A5PKW4', 'P62330'),
#  ('O00267', 'P63272'),
#  ('O00311', 'Q9UBU7'),
#  ('O14641', 'O15169'),
#  ('O14641', 'O15169-2')]

# %%
unique_pairs_correlation_data = pd.DataFrame(unique_pairs, columns=["PROTEIN", "INTERACTOR"])
unique_pairs_correlation_data.head()
# Out:
#   PROTEIN INTERACTOR
# 0  A5PKW4     P62330
# 1  O00267     P63272
# 2  O00311     Q9UBU7
# 3  O14641     O15169
# 4  O14641   O15169-2

# %%
from itertools import combinations

# %%
from tqdm.notebook import tqdm

# %%
corr_scores = []
for pair in tqdm(unique_pairs):
    query = get_entries_with_pair(pair[0], pair[1], training_data)
    corr_score_values = []
    data_indices = query.index
    for a, b in combinations(data_indices, 2):
        corr_score_values.append(
            pearsonr(query.loc[a, :][4:], query.loc[b, :][4:])[0]
        )

    corr_score = round( (sum(corr_score_values) / len(corr_score_values)), 2 )
    
    corr_scores.append(corr_score)
# Out:
#   0%|          | 0/383 [00:00<?, ?it/s]

# %%
unique_pairs_correlation_data["PEARSON_CORR"] = corr_scores

# %%
unique_pairs_correlation_data["PEARSON_CORR"].value_counts()
# Out:
# NOT APPLICABLE    383
# Name: PEARSON_CORR, dtype: int64

# %%
unique_pairs_correlation_data["PEARSON_CORR"].value_counts()
# Out:
# NOT APPLICABLE    322
# 1.0                20
# 0.99                9
# 0.48                7
# 0.66                2
# 0.94                2
# 0.87                1
# 0.77                1
# 0.52                1
# 0.98                1
# 0.5                 1
# 0.88                1
# 0.93                1
# Name: PEARSON_CORR, dtype: int64

# %%
unique_pairs_correlation_data.head()
# Out:
#   PROTEIN MUTATION    PEARSON_CORR
# 0  A5PKW4    E621K  NOT APPLICABLE
# 1  O00267    I194V  NOT APPLICABLE
# 2  O00311     I99L  NOT APPLICABLE
# 3  O00311     I99T  NOT APPLICABLE
# 4  O00311    K416T  NOT APPLICABLE

# %%
get_entries_with_pair("A5PKW4", "E621K", training_data)
# Out:
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 185                      0     A5PKW4    E621K                P62330
#
#      Template_sequence_identity  Alignment_score  \
# 185                      0.3595         0.302542
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 185                                 0.7278                    0.669387
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 185  -0.321962        0.990991  ...                   369.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 185                 58.6922                  58.5371                 264.514
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 185                  264.491                      637.52
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 185                     335.095                972.62
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 185                        3.35756                          3.0706
#
# [1 rows x 62 columns]

# %%
unique_pairs_correlation_data.to_csv("pairs_corr_interactor_entries.csv")

# %%
len(set(zip(training_data["UniProt_ID"], training_data["Mutation"])))
# Out:
# 369

# %%
unique_pairs_correlation_data[~unique_pairs_correlation_data.duplicated()]
# Out:
#       PROTEIN MUTATION    PEARSON_CORR
# 0      Q9BPZ3    F118A  NOT APPLICABLE
# 1      P01116     Y40C  NOT APPLICABLE
# 2      Q96QK1    F534D  NOT APPLICABLE
# 4    O43521-3     G66A            0.99
# 11     Q13418    Q362H  NOT APPLICABLE
# ..        ...      ...             ...
# 726    P51587   V1532F  NOT APPLICABLE
# 730  P30622-2    K252A  NOT APPLICABLE
# 734    P84243     Q94A  NOT APPLICABLE
# 736    Q96QK1    L589D  NOT APPLICABLE
# 738    P23297     F72L  NOT APPLICABLE
#
# [369 rows x 3 columns]

# %%
unique_pairs_correlation_data.head()
# Out:
#     PROTEIN MUTATION    PEARSON_CORR
# 0    Q9BPZ3    F118A  NOT APPLICABLE
# 1    P01116     Y40C  NOT APPLICABLE
# 2    Q96QK1    F534D  NOT APPLICABLE
# 3    Q96QK1    F534D  NOT APPLICABLE
# 4  O43521-3     G66A            0.99

# %%
unique_pairs_correlation_data.to_csv("pairs_corr_values")

# %%
get_entries_with_pair("O43521-3", "G66A", training_data)
# Out:
#      Mutation_Effect_Label UniProt_ID Mutation Interactor_UniProt_ID  \
# 4                        0   O43521-3     G66A                Q07812
# 5                        0   O43521-3     G66A              Q07812-2
# 6                        0   O43521-3     G66A              Q07812-4
# 7                        0   O43521-3     G66A              Q07812-5
# 8                        0   O43521-3     G66A              Q07812-6
# 9                        0   O43521-3     G66A              Q07812-7
# 10                       0   O43521-3     G66A              Q07812-8
# 34                       0   O43521-3     G66A                Q92843
# 35                       0   O43521-3     G66A              Q92843-2
# 427                      0   O43521-3     G66A                P10415
# 428                      0   O43521-3     G66A              P10415-2
# 637                      0   O43521-3     G66A              Q07817-3
# 638                      0   O43521-3     G66A                Q07817
#
#      Template_sequence_identity  Alignment_score  \
# 4                        1.0000         0.714286
# 5                        1.0000         0.714286
# 6                        1.0000         0.657143
# 7                        1.0000         0.657143
# 8                        1.0000         0.657143
# 9                        1.0000         0.714286
# 10                       1.0000         0.714286
# 34                       1.0000         0.714286
# 35                       1.0000         0.714286
# 427                      0.8077         0.607148
# 428                      1.0000         0.714286
# 637                      1.0000         0.714286
# 638                      1.0000         0.714286
#
#      Interactor_template_sequence_identity  Interactor_alignment_score  \
# 4                                   0.3007                    0.222028
# 5                                   0.2774                    0.195757
# 6                                   0.3267                    0.246963
# 7                                   0.3623                    0.161145
# 8                                   0.3444                    0.287848
# 9                                   0.2826                    0.228268
# 10                                  0.2695                    0.217124
# 34                                  0.5278                    0.411415
# 35                                  0.5324                    0.482834
# 427                                 0.4611                    0.457246
# 428                                 0.6505                    0.435452
# 637                                 1.0000                    0.662500
# 638                                 0.6804                    0.675489
#
#      Final_ddG  ProtBert_score  ...  number_of_residues_mut  \
# 4     0.683334       -0.051025  ...                   202.0
# 5     1.695590       -0.065221  ...                   200.0
# 6     1.349830       -0.066371  ...                   156.0
# 7     1.032800       -0.083838  ...                   187.0
# 8     1.619190       -0.044318  ...                   116.0
# 9     0.984865       -0.036998  ...                   182.0
# 10    1.662730       -0.055153  ...                   189.0
# 34    1.371000       -0.102369  ...                   203.0
# 35    1.205380       -0.101746  ...                   179.0
# 427   0.510358       -0.044520  ...                   229.0
# 428   0.945436       -0.082937  ...                   181.0
# 637   0.726367       -0.099033  ...                   184.0
# 638   1.218850       -0.055623  ...                   219.0
#
#      IntraclashesEnergy1_wt  IntraclashesEnergy1_mut  IntraclashesEnergy2_wt  \
# 4                   3.74828                  3.76142                 41.5937
# 5                   4.17468                  4.26566                 45.2100
# 6                   2.16863                  2.19777                 82.9722
# 7                   1.96537                  1.97697                225.5630
# 8                   2.15393                  2.16121                 35.4722
# 9                   5.26678                  5.36095                 48.6238
# 10                  4.02917                  4.08328                 49.7783
# 34                  3.48179                  3.56202                 65.6840
# 35                  2.51989                  2.61362                 44.8595
# 427                 5.88486                  6.57183                 93.3738
# 428                 2.67195                  2.73996                 31.6189
# 637                 3.34555                  3.48355                 29.6167
# 638                 7.00039                  7.10651                264.6130
#
#      IntraclashesEnergy2_mut  Interface_hydrophobic_area  \
# 4                    41.5937                     405.510
# 5                    45.2100                     521.820
# 6                    82.9722                     421.435
# 7                   225.5630                     447.125
# 8                    35.4722                     326.765
# 9                    48.6238                     453.075
# 10                   49.7783                     402.525
# 34                   65.6840                     525.270
# 35                   44.8595                     474.225
# 427                  93.3738                     414.305
# 428                  31.6189                     421.875
# 637                  29.6167                     544.650
# 638                 264.6130                     587.710
#
#      Interface_hydrophilic_area  Interface_total_area  \
# 4                       273.740               679.245
# 5                       306.275               828.095
# 6                       257.725               679.160
# 7                       288.435               735.565
# 8                       193.060               519.825
# 9                       288.960               742.035
# 10                      231.455               633.985
# 34                      283.160               808.430
# 35                      213.525               687.750
# 427                     244.975               659.285
# 428                     272.215               694.090
# 637                     261.940               806.590
# 638                     247.505               835.210
#
#      Interface_contact_distance_wt  Interface_contact_distance_mut
# 4                          3.37301                         3.22505
# 5                          3.44165                         3.02304
# 6                          3.39501                         2.64792
# 7                          3.45953                         2.63225
# 8                          3.39503                         2.62549
# 9                          3.37259                         3.21556
# 10                         3.41580                         3.19863
# 34                         3.41477                         3.18362
# 35                         3.41566                         3.19828
# 427                        3.55303                         3.19191
# 428                        3.41921                         3.20397
# 637                        3.36459                         3.24877
# 638                        3.14969                         3.07616
#
# [13 rows x 62 columns]
