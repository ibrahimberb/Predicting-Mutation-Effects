# %% [markdown]
# # Prepare Results

# %%
import sys 
import os
from pathlib import Path
# Path.cwd().parent
sys.path.append(os.path.dirname(Path.cwd().parent))

from benchmark.benchmark_utils import ReadyResults
import pandas as pd

# Reflect changes in the modules immediately.
# %load_ext autoreload
# %autoreload 2

# %%
interface_results = ReadyResults("allresults_2021-11-07.txt").get_interface_ready_results()
# Out:
# Separating Core and Interface entries ..
# Core data dimensions: (3, 103)
# Core data preview:
#   UniProt_ID Mutation Interactor_UniProt_ID
# 0     P28482    E322K                     -
# 1     P42336    G363A                     -
# 2     P42336    K111N                     -
#
# Interface data dimensions: (76, 103)
# Interface data preview:
#   UniProt_ID Mutation Interactor_UniProt_ID
# 0     P42336   M1043V                Q13535
# 1     P42336   M1043V              Q13535-2
# 2     P42336   M1043V              Q13535-3
#
# Dropping duplicated entries ..
# Size of dataframe before dropping duplicated entries: (3, 103)
# Size of dataframe  after dropping duplicated entries: (3, 103)
# Dropping self interactions ..
# Dropping duplicated entries ..
# Size of dataframe before dropping duplicated entries: (73, 103)
# Size of dataframe  after dropping duplicated entries: (73, 103)

# %%
interface_results
# Out:
#    Input_identifier UniProt_ID Mutation Status       Type COSMIC_mut_ID  \
# 0            P42336     P42336   M1043V   done  interface     COSM94983
# 1            P42336     P42336   M1043V   done  interface     COSM94983
# 2            P42336     P42336   M1043V   done  interface     COSM94983
# 3            P42336     P42336   M1043V   done  interface     COSM94983
# 4            P01112     P01112     G12D   done  interface     COSM99915
# ..              ...        ...      ...    ...        ...           ...
# 68           P04637     P04637    R273H   done  interface     COSM99729
# 69           P04637     P04637    R273H   done  interface     COSM99729
# 70           Q969H0     Q969H0    R505G   done  interface     COSM99606
# 71           Q969H0     Q969H0    R505G   done  interface     COSM99606
# 72           Q969H0     Q969H0    R505G   done  interface     COSM99606
#
#    ClinVar_mut_ID UniProt_mut_ID       Domain_name       Domain_clan  ...  \
# ...

# %%
import pandas as pd
from utils import ReadyResults

# Reflect changes in the modules immediately.
# %load_ext autoreload
# %autoreload 2

# %%
results = pd.read_csv("allresults_2021-11-07.txt", sep='\t', low_memory=False)

# %%
interface_results = ReadyResults(results).get_interface_ready_results()
# Out:
# Separating Core and Interface entries ..
# Core data dimensions: (3, 103)
# Core data preview:
#   UniProt_ID Mutation Interactor_UniProt_ID
# 0     P28482    E322K                     -
# 1     P42336    G363A                     -
# 2     P42336    K111N                     -
#
# Interface data dimensions: (76, 103)
# Interface data preview:
#   UniProt_ID Mutation Interactor_UniProt_ID
# 0     P42336   M1043V                Q13535
# 1     P42336   M1043V              Q13535-2
# 2     P42336   M1043V              Q13535-3
#
# Dropping duplicated entries ..
# Size of dataframe before dropping duplicated entries: (3, 103)
# Size of dataframe  after dropping duplicated entries: (3, 103)
# Dropping self interactions ..
# Dropping duplicated entries ..
# Size of dataframe before dropping duplicated entries: (73, 103)
# Size of dataframe  after dropping duplicated entries: (73, 103)
